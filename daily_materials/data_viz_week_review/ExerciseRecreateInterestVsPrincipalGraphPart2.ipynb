# %% [markdown]
# <h1>Exercise recreate interest vs principal graph</h1>
#
# <b>Objectives</b>
# <ul>
#     <li>Task</li>
# </ul>

# %% [markdown]
# <h2>Task</h2>
# The dataset given to you <a href="https://s3.amazonaws.com/General_V88/boomyeah2015/codingdojo/curriculum/content/chapter/mortgages.csv">here (mortgages.csv)</a>
# is the mortgage dataset used previously in this course.  Your goal is to reproduce the graph.  Don't worry if the graph looks exactly the same. It is possible you can create a more visually appealing and informative graph. The black line is the 30 year mortgage at 5% and the blue line is the 30 year mortgage at 3%. What is graphed is the cumulative interest paid over the course of the loan.
#
# Hint: plt.xticks(fontsize = 15) and plt.yticks(fontsize = 15) might be useful to make the ticks bigger.

# %%
from IPython.display import Image
Image('images/ExerciseRecreateGraphPart2_q2q123912310.png')
