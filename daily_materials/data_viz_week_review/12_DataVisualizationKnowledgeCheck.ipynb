# %% [markdown]
# <h1>Data Visualization Knowledge Check</h1>
#
# <b>Objectives</b>
# <ul>
# <li>Mount data</li>
# <li>Answer quiz questions (select which is true)</li>
# </ul>

# %% [markdown]
# <h2>Mount data</h2>

# %%
#from google.colab import drive
#drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-d5df0069828e> in <module>
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/drive')
#
# ModuleNotFoundError: No module named 'google'

# %% [markdown]
# <h2>Answer quiz questions (select which is true)</h2>

# %%
from IPython.display import Image
Image('images/QUIZAllDataVisualizationImages192312909012313.png')

# %% [markdown]
# When the code from Image A was executed, it produced the saved image B was produced, Why was the legend cutoff?
# <ul>
# <li>The image was saved in an unsupported format.</li>
# <li>The legend location is outside the area for the figure.</li>
# </ul>

# %% [markdown]
# In image B, what does plt.tight_layout likely do??
# <ul>
# <li>It breaks the graph into multiple pieces</li>
# <li>Adjusts subplot parameters so that the subplot fits in the figure area</li>
# </ul>

# %% [markdown]
# What are some potential disadvantages of the Matplotlib library versus seaborn??
# <ul>
# <li>Defaults are not ideal (no gridlines, white background, etc)</li>
# <li>Library is relatively low-level</li>
# <li>Lack of integration with pandas data structures (though this is being improved)</li>
# <li>All of the above.</li>
# </ul>
